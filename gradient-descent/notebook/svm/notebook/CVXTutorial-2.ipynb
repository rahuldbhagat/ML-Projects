# %% [markdown]
# # **Linear Program**

# %%
# !pip install cvxpy

# %%
import cvxpy as cp
import numpy as np

# %%
x=cp.Variable(2)

# %%
x=cp.Variable(5)
cp.norm(x,1)
# Out:
# Expression(CONVEX, NONNEGATIVE, ())

# %%
cp.exp(x)
# Out:
# Expression(CONVEX, NONNEGATIVE, (5,))

# %%
cp.log(x)
# Out:
# Expression(CONCAVE, UNKNOWN, (5,))

# %%
cp.norm(x,1)+cp.exp(x)
# Out:
# Expression(CONVEX, NONNEGATIVE, (5,))

# %%
x=cp.Variable()
y=cp.Variable()
cp.kl_div(x,y)
# Out:
# Expression(CONVEX, NONNEGATIVE, ())

# %%
cp.power(x,4)
# Out:
# Expression(CONVEX, NONNEGATIVE, ())

# %%
cp.power(x,1)+cp.power(y,1)
# Out:
# Expression(AFFINE, UNKNOWN, ())

# %%
cp.power(x,1)+cp.power(y,1)+cp.norm(x,1)
# Out:
# Expression(CONVEX, UNKNOWN, ())

# %%
#Problem of class

# %%
x=cp.Variable(2)

# %%
A = np.array([[-2,-1], [-1,-2]])
A
# Out:
# array([[-2, -1],
#        [-1, -2]])

# %%
b=np.array([-8,-10]).T
b
# Out:
# array([ -8, -10])

# %%
c=np.array([50,70]).T
c
# Out:
# array([50, 70])

# %%
x = cp.Variable(2)
prob = cp.Problem(cp.Minimize(c.T@x),
                 [A @ x <= b])
prob.solve()
# Print result.
print("\nThe optimal value is", prob.value)
print("A solution x is")
print(x.value)
# Out:
# The optimal value is 379.9999999903208
# A solution x is
# [2. 4.]
